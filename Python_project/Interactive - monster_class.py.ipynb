# %% [markdown]
# Connected to Python 3.12.2

# %%
#Practicing organizing code by using classes, I want to create monsters that can attack eachother, but each have different attributes, abilities ect.

class Monster:
    #Define the monster
    def __init__(self, monster, level, category, armour_level, life, weapon_level):
        self.monster = monster
        self.level = level
        self.category = category
        self.armour_level = armour_level
        self.life = life
        self.weapon_level = weapon_level

    def damage(self, life_damage):
        life_damage = self.life - self.weapon_level
        return life_damage
    


ogre = Monster(monster = 'ogre', level = 50, category = 'giant', armour_level = 1, arm_durability = 100, arm_health_pool = 100, life = 100, weapon_level = 6, wep_durability = 100, wep_health_pool = 100)

human = Monster(monster = 'Chad', level = 30, category = 'Humanoid', armour_level = 3, arm_durability = 100, arm_health_pool = 100, life = 100, weapon_level = 3, wep_durability = 100, wep_health_pool = 100)

bear = Monster(monster = 'Bear', level = 20, category = 'Mammal', armour_level = 0, arm_durability = 0, arm_health_pool = 100, life = 100, weapon_level = 3, wep_durability = 100, wep_health_pool = 100)

gorilla = Monster(monster = 'Harambe', level = 30, category = 'Mammal', armour_level = 3, arm_durability = 100, arm_health_pool = 100, life = 100, weapon_level = 3, wep_durability = 100, wep_health_pool = 100)

garden_gnome = Monster(monster = 'Gnome', level = 100, category = 'Lawn Decor', armour_level = 6, arm_durability = 100, arm_health_pool = 100, life = 100, weapon_level = 6, wep_durability = 100, wep_health_pool = 100)

def main() -> None:
    monsters = {
        'ogre': ogre,
        'human': human,
        'bear': bear,
        'gorilla': gorilla,
        'garden gnome': garden_gnome
    }

    Fighter1 = input('choose your monster, "Ogre, Human, Bear, Gorilla, or Garden Gnome: ').strip().lower()
    Fighter2 = input('choose opposing monster, "Ogre, Human, Bear, Gorilla, or Garden Gnome: ').strip().lower()

    if Fighter1 in ['ogre','human','bear','gorilla','garden','gnome','garden gnome','gardengnome']:
        print(f'you have selected {Fighter1} and {Fighter2}')
    else:
        print('Invalid creature, please select another')
    
    Fighter1 = monsters[Fighter1]
    Fighter2 = monsters[Fighter2]

    while monsters[Fighter1].life > 0 and monsters[Fighter2] > 0:

        monsters[Fighter1].attack(monsters[Fighter2])

        if monsters[Fighter2].life < 0:
            print(f'{monsters[Fighter2].monster} is defeated! {monsters[Fighter1.monster]} is victorious!')
            break
        
        monsters[Fighter2].attack(monsters[Fighter1])
        if monsters[Fighter2] < 0:
            print(f'{monsters[Fighter1].monster} is defeated! {monsters[Fighter2].monster} is victorious!')
    

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File Daryliost\animated-octo-palm-tree\Python_project\monster_class.py:19
#      14         life_damage = self.life - self.weapon_level
#      15         return life_damage
# ---> 19 ogre = Monster(monster = 'ogre', level = 50, category = 'giant', armour_level = 1, arm_durability = 100, arm_health_pool = 100, life = 100, weapon_level = 6, wep_durability = 100, wep_health_pool = 100)
#      21 human = Monster(monster = 'Chad', level = 30, category = 'Humanoid', armour_level = 3, arm_durability = 100, arm_health_pool = 100, life = 100, weapon_level = 3, wep_durability = 100, wep_health_pool = 100)
#      23 bear = Monster(monster = 'Bear', level = 20, category = 'Mammal', armour_level = 0, arm_durability = 0, arm_health_pool = 100, life = 100, weapon_level = 3, wep_durability = 100, wep_health_pool = 100)
#
# TypeError: Monster.__init__() got an unexpected keyword argument 'arm_durability'

# %%
#Practicing organizing code by using classes, I want to create monsters that can attack eachother, but each have different attributes, abilities ect.

class Monster:
    #Define the monster
    def __init__(self, monster, level, category, armour_level, life, weapon_level):
        self.monster = monster
        self.level = level
        self.category = category
        self.armour_level = armour_level
        self.life = life
        self.weapon_level = weapon_level

    def damage(self, life_damage):
        life_damage = self.life - self.weapon_level
        return life_damage
    


ogre = Monster(monster = 'ogre', level = 50, category = 'giant', armour_level = 1,life = 100, weapon_level = 6,)

human = Monster(monster = 'Chad', level = 30, category = 'Humanoid', armour_level = 3, life = 100, weapon_level = 3,)

bear = Monster(monster = 'Bear', level = 20, category = 'Mammal', armour_level = 0, life = 100, weapon_level = 3,)

gorilla = Monster(monster = 'Harambe', level = 30, category = 'Mammal', armour_level = 3, life = 100, weapon_level = 3,)

garden_gnome = Monster(monster = 'Gnome', level = 100, category = 'Lawn Decor', armour_level = 6, life = 100, weapon_level = 6,)

def main() -> None:
    monsters = {
        'ogre': ogre,
        'human': human,
        'bear': bear,
        'gorilla': gorilla,
        'garden gnome': garden_gnome
    }

    Fighter1 = input('choose your monster, "Ogre, Human, Bear, Gorilla, or Garden Gnome: ').strip().lower()
    Fighter2 = input('choose opposing monster, "Ogre, Human, Bear, Gorilla, or Garden Gnome: ').strip().lower()

    if Fighter1 in ['ogre','human','bear','gorilla','garden','gnome','garden gnome','gardengnome']:
        print(f'you have selected {Fighter1} and {Fighter2}')
    else:
        print('Invalid creature, please select another')
    
    Fighter1 = monsters[Fighter1]
    Fighter2 = monsters[Fighter2]

    while monsters[Fighter1].life > 0 and monsters[Fighter2] > 0:

        monsters[Fighter1].attack(monsters[Fighter2])

        if monsters[Fighter2].life < 0:
            print(f'{monsters[Fighter2].monster} is defeated! {monsters[Fighter1.monster]} is victorious!')
            break
        
        monsters[Fighter2].attack(monsters[Fighter1])
        if monsters[Fighter2] < 0:
            print(f'{monsters[Fighter1].monster} is defeated! {monsters[Fighter2].monster} is victorious!')
    

if __name__ == '__main__':
    main()
# Out:
# you have selected ogre and human
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File Daryliost\animated-octo-palm-tree\Python_project\monster_class.py:63
#      59             print(f'{monsters[Fighter1].monster} is defeated! {monsters[Fighter2].monster} is victorious!')
#      62 if __name__ == '__main__':
# ---> 63     main()
#
# File Daryliost\animated-octo-palm-tree\Python_project\monster_class.py:49
#      46 Fighter1 = monsters[Fighter1]
#      47 Fighter2 = monsters[Fighter2]
# ---> 49 while monsters[Fighter1].life > 0 and monsters[Fighter2] > 0:
#      51     monsters[Fighter1].attack(monsters[Fighter2])
#      53     if monsters[Fighter2].life < 0:
#
# KeyError: <__main__.Monster object at 0x0000021540B0C830>

# %%
#Practicing organizing code by using classes, I want to create monsters that can attack eachother, but each have different attributes, abilities ect.

class Monster:
    #Define the monster
    def __init__(self, monster, level, category, armour_level, life, weapon_level):
        self.monster = monster
        self.level = level
        self.category = category
        self.armour_level = armour_level
        self.life = life
        self.weapon_level = weapon_level

    def damage(self, life_damage):
        self.life -= life_damage
        return self.life

    def attack(self, other):
        damage_dealt = self.weapon_level - other.armour_level
        if damage_dealt > 0:
            other.damage(damage_dealt)
        else:
            other.damage(1)
    


ogre = Monster(monster = 'ogre', level = 50, category = 'giant', armour_level = 1,life = 100, weapon_level = 6,)

human = Monster(monster = 'Chad', level = 30, category = 'Humanoid', armour_level = 3, life = 100, weapon_level = 3,)

bear = Monster(monster = 'Bear', level = 20, category = 'Mammal', armour_level = 0, life = 100, weapon_level = 3,)

gorilla = Monster(monster = 'Harambe', level = 30, category = 'Mammal', armour_level = 3, life = 100, weapon_level = 3,)

garden_gnome = Monster(monster = 'Gnome', level = 100, category = 'Lawn Decor', armour_level = 6, life = 100, weapon_level = 6,)

def main() -> None:
    monsters = {
        'ogre': ogre,
        'human': human,
        'bear': bear,
        'gorilla': gorilla,
        'garden gnome': garden_gnome
    }

    Fighter1 = input('choose your monster, "Ogre, Human, Bear, Gorilla, or Garden Gnome: ').strip().lower()
    Fighter2 = input('choose opposing monster, "Ogre, Human, Bear, Gorilla, or Garden Gnome: ').strip().lower()

    if Fighter1 in ['ogre','human','bear','gorilla','garden','gnome','garden gnome','gardengnome']:
        
        while Fighter1.life > 0 and Fighter2.life > 0:

            Fighter1.attack(Fighter2)

            if Fighter2.life <= 0:
                print(f'{Fighter2.monster} is defeated! {Fighter1.monster} is victorious!')
                break
            
            Fighter2.attack(Fighter1)
            if Fighter1.life <= 0:
                print(f'{Fighter1.monster} is defeated! {Fighter2.monster} is victorious!')
            if monsters[Fighter2].life < 0:
                print(f'{monsters[Fighter2].monster} is defeated! {monsters[Fighter1.monster]} is victorious!')
                break
            
            monsters[Fighter2].attack(monsters[Fighter1])
            if monsters[Fighter2] < 0:
                print(f'{monsters[Fighter1].monster} is defeated! {monsters[Fighter2].monster} is victorious!')
        

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File Daryliost\animated-octo-palm-tree\Python_project\monster_class.py:71
#      67                 print(f'{monsters[Fighter1].monster} is defeated! {monsters[Fighter2].monster} is victorious!')
#      70 if __name__ == '__main__':
# ---> 71     main()
#
# File Daryliost\animated-octo-palm-tree\Python_project\monster_class.py:50
#      46 Fighter2 = input('choose opposing monster, "Ogre, Human, Bear, Gorilla, or Garden Gnome: ').strip().lower()
#      48 if Fighter1 in ['ogre','human','bear','gorilla','garden','gnome','garden gnome','gardengnome']:
# ---> 50     while Fighter1.life > 0 and Fighter2.life > 0:
#      52         Fighter1.attack(Fighter2)
#      54         if Fighter2.life <= 0:
#
# AttributeError: 'str' object has no attribute 'life'

# %%
#Practicing organizing code by using classes, I want to create monsters that can attack eachother, but each have different attributes, abilities ect.

class Monster:
    #Define the monster
    def __init__(self, monster, level, category, armour_level, life, weapon_level):
        self.monster = monster
        self.level = level
        self.category = category
        self.armour_level = armour_level
        self.life = life
        self.weapon_level = weapon_level

    def damage(self, life_damage):
        self.life -= life_damage
        return self.life

    def attack(self, other):
        damage_dealt = self.weapon_level - other.armour_level
        if damage_dealt > 0:
            other.damage(damage_dealt)
        else:
            other.damage(1)
    


ogre = Monster(monster = 'ogre', level = 50, category = 'giant', armour_level = 1,life = 100, weapon_level = 6,)

human = Monster(monster = 'Chad', level = 30, category = 'Humanoid', armour_level = 3, life = 100, weapon_level = 3,)

bear = Monster(monster = 'Bear', level = 20, category = 'Mammal', armour_level = 0, life = 100, weapon_level = 3,)

gorilla = Monster(monster = 'Harambe', level = 30, category = 'Mammal', armour_level = 3, life = 100, weapon_level = 3,)

garden_gnome = Monster(monster = 'Gnome', level = 100, category = 'Lawn Decor', armour_level = 6, life = 100, weapon_level = 6,)

def main() -> None:
    monsters = {
        'ogre': ogre,
        'human': human,
        'bear': bear,
        'gorilla': gorilla,
        'garden gnome': garden_gnome
    }

    Fighter1 = input('choose your monster, "Ogre, Human, Bear, Gorilla, or Garden Gnome: ').strip().lower()
    Fighter2 = input('choose opposing monster, "Ogre, Human, Bear, Gorilla, or Garden Gnome: ').strip().lower()

    if Fighter1 in monsters and Fighter2 in monsters:
        fighter1 = monsters[Fighter1]
        fighter2 = monsters[Fighter2]
        
        while fighter1.life > 0 and fighter2.life > 0:

            fighter1.attack(fighter2)

            if fighter2.life <= 0:
                print(f'{fighter2.monster} is defeated! {fighter1.monster} is victorious!')
                break
            
            fighter2.attack(fighter1)
            if fighter1.life <= 0:
                print(f'{fighter1.monster} is defeated! {fighter2.monster} is victorious!')
        

if __name__ == '__main__':
    main()
# Out:
# Chad is defeated! ogre is victorious!

# %%
#Practicing organizing code by using classes, I want to create monsters that can attack eachother, but each have different attributes, abilities ect.

class Monster:
    #Define the monster
    def __init__(self, monster, level, category, armour_level, life, weapon_level):
        self.monster = monster
        self.level = level
        self.category = category
        self.armour_level = armour_level
        self.life = life
        self.weapon_level = weapon_level

    def damage(self, life_damage):
        self.life -= life_damage
        return self.life

    def attack(self, other):
        damage_dealt = self.weapon_level - other.armour_level
        if damage_dealt > 0:
            other.damage(damage_dealt)
        else:
            other.damage(1)
    


ogre = Monster(monster = 'ogre', level = 50, category = 'giant', armour_level = 1,life = 100, weapon_level = 6,)

human = Monster(monster = 'Chad', level = 30, category = 'Humanoid', armour_level = 3, life = 100, weapon_level = 3,)

bear = Monster(monster = 'Bear', level = 20, category = 'Mammal', armour_level = 0, life = 100, weapon_level = 3,)

gorilla = Monster(monster = 'Harambe', level = 30, category = 'Mammal', armour_level = 3, life = 100, weapon_level = 3,)

garden_gnome = Monster(monster = 'Gnome', level = 100, category = 'Lawn Decor', armour_level = 6, life = 100, weapon_level = 6,)

def main() -> None:
    monsters = {
        'ogre': ogre,
        'human': human,
        'bear': bear,
        'gorilla': gorilla,
        'garden gnome': garden_gnome
    }

    Fighter1 = input('choose your monster, "Ogre, Human, Bear, Gorilla, or Garden Gnome: ').strip().lower()
    Fighter2 = input('choose opposing monster, "Ogre, Human, Bear, Gorilla, or Garden Gnome: ').strip().lower()

    if Fighter1 in monsters and Fighter2 in monsters:
        fighter1 = monsters[Fighter1]
        fighter2 = monsters[Fighter2]
        
        while fighter1.life > 0 and fighter2.life > 0:

            fighter1.attack(fighter2)

            if fighter2.life <= 0:
                print(f'{fighter2.monster} is defeated! {fighter1.monster} is victorious!')
                break
            
            fighter2.attack(fighter1)
            if fighter1.life <= 0:
                print(f'{fighter1.monster} is defeated! {fighter2.monster} is victorious!')
        

if __name__ == '__main__':
    main()
# Out:
# Bear is defeated! Gnome is victorious!

# %%
#Practicing organizing code by using classes, I want to create monsters that can attack eachother, but each have different attributes, abilities ect.

class Monster:
    #Define the monster
    def __init__(self, monster, level, category, armour_level, life, weapon_level):
        self.monster = monster
        self.level = level
        self.category = category
        self.armour_level = armour_level
        self.life = life
        self.weapon_level = weapon_level

    def damage(self, life_damage):
        self.life -= life_damage
        return self.life

    def attack(self, other):
        damage_dealt = self.weapon_level - other.armour_level
        if damage_dealt > 0:
            other.damage(damage_dealt)
        else:
            other.damage(1)
    


ogre = Monster(monster = 'ogre', level = 50, category = 'giant', armour_level = 1,life = 100, weapon_level = 6,)

human = Monster(monster = 'Chad', level = 30, category = 'Humanoid', armour_level = 3, life = 100, weapon_level = 3,)

bear = Monster(monster = 'Bear', level = 20, category = 'Mammal', armour_level = 0, life = 100, weapon_level = 3,)

gorilla = Monster(monster = 'Harambe', level = 30, category = 'Mammal', armour_level = 3, life = 100, weapon_level = 3,)

garden_gnome = Monster(monster = 'Gnome', level = 100, category = 'Lawn Decor', armour_level = 6, life = 100, weapon_level = 6,)

def main() -> None:
    monsters = {
        'ogre': ogre,
        'human': human,
        'bear': bear,
        'gorilla': gorilla,
        'garden gnome': garden_gnome
    }

    Fighter1 = input('choose your monster, "Ogre, Human, Bear, Gorilla, or Garden Gnome: ').strip().lower()
    Fighter2 = input('choose opposing monster, "Ogre, Human, Bear, Gorilla, or Garden Gnome: ').strip().lower()

    if Fighter1 in monsters and Fighter2 in monsters:
        fighter1 = monsters[Fighter1]
        fighter2 = monsters[Fighter2]
        
        while fighter1.life > 0 and fighter2.life > 0:

            fighter1.attack(fighter2)

            if fighter2.life <= 0:
                print(f'{fighter2.monster} is defeated! {fighter1.monster} is victorious!')
                break
            
            fighter2.attack(fighter1)
            if fighter1.life <= 0:
                print(f'{fighter1.monster} is defeated! {fighter2.monster} is victorious!')
        

if __name__ == '__main__':
    main()
# Out:
# ogre is defeated! Gnome is victorious!

# %%
#Practicing organizing code by using classes, I want to create monsters that can attack eachother, but each have different attributes, abilities ect.

class Monster:
    #Define the monster
    def __init__(self, monster, level, category, armour_level, life, weapon_level):
        self.monster = monster
        self.level = level
        self.category = category
        self.armour_level = armour_level
        self.life = life
        self.weapon_level = weapon_level

    def damage(self, life_damage):
        self.life -= life_damage
        return self.life

    def attack(self, other):
        damage_dealt = self.weapon_level - other.armour_level
        if damage_dealt > 0:
            other.damage(damage_dealt)
        else:
            other.damage(1)
    


ogre = Monster(monster = 'ogre', level = 50, category = 'giant', armour_level = 1,life = 100, weapon_level = 6,)

human = Monster(monster = 'Chad', level = 30, category = 'Humanoid', armour_level = 3, life = 100, weapon_level = 3,)

bear = Monster(monster = 'Bear', level = 20, category = 'Mammal', armour_level = 0, life = 100, weapon_level = 3,)

gorilla = Monster(monster = 'Harambe', level = 30, category = 'Mammal', armour_level = 3, life = 100, weapon_level = 3,)

garden_gnome = Monster(monster = 'Gnome', level = 100, category = 'Lawn Decor', armour_level = 6, life = 100, weapon_level = 6,)

def main() -> None:
    monsters = {
        'ogre': ogre,
        'human': human,
        'bear': bear,
        'gorilla': gorilla,
        'garden gnome': garden_gnome
    }

    Fighter1 = input('choose your monster, "Ogre, Human, Bear, Gorilla, or Garden Gnome: ').strip().lower()
    Fighter2 = input('choose opposing monster, "Ogre, Human, Bear, Gorilla, or Garden Gnome: ').strip().lower()

    if Fighter1 in monsters and Fighter2 in monsters:
        fighter1 = monsters[Fighter1]
        fighter2 = monsters[Fighter2]
        
        while fighter1.life > 0 and fighter2.life > 0:

            fighter1.attack(fighter2)
            print(f'{fighter1.monster.capitalize} swings at {fighter2.monster.capitalize} dealing {fighter1.attack} damage!')

            if fighter2.life <= 0:
                print(f'{fighter2.monster.capitalize} is defeated! {fighter1.monster.capitalize} is victorious!')
                break
            
            fighter2.attack(fighter1)
            print(f'{fighter2.monster.capitalize} swings at {fighter2.monster.capitalize} dealing {fighter2.attack} damage!')

            if fighter1.life <= 0:
                print(f'{fighter1.monster.capitalize} is defeated! {fighter2.monster.capitalize} is victorious!')
        

if __name__ == '__main__':
    main()
# Out:
# <built-in method capitalize of str object at 0x00000215409C4090> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2EDE0>> damage!
# <built-in method capitalize of str object at 0x00000215409A3960> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F6B0>> damage!
# <built-in method capitalize of str object at 0x00000215409C4090> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2EDE0>> damage!
# <built-in method capitalize of str object at 0x00000215409A3960> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F6B0>> damage!
# <built-in method capitalize of str object at 0x00000215409C4090> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2EDE0>> damage!
# <built-in method capitalize of str object at 0x00000215409A3960> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F6B0>> damage!
# <built-in method capitalize of str object at 0x00000215409C4090> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2EDE0>> damage!
# <built-in method capitalize of str object at 0x00000215409A3960> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F6B0>> damage!
# <built-in method capitalize of str object at 0x00000215409C4090> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2EDE0>> damage!
# <built-in method capitalize of str object at 0x00000215409A3960> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F6B0>> damage!
# <built-in method capitalize of str object at 0x00000215409C4090> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2EDE0>> damage!
# <built-in method capitalize of str object at 0x00000215409A3960> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F6B0>> damage!
# <built-in method capitalize of str object at 0x00000215409C4090> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2EDE0>> damage!
# <built-in method capitalize of str object at 0x00000215409A3960> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F6B0>> damage!
# <built-in method capitalize of str object at 0x00000215409C4090> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2EDE0>> damage!
# <built-in method capitalize of str object at 0x00000215409A3960> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F6B0>> damage!
# <built-in method capitalize of str object at 0x00000215409C4090> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2EDE0>> damage!
# <built-in method capitalize of str object at 0x00000215409A3960> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F6B0>> damage!
# <built-in method capitalize of str object at 0x00000215409C4090> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2EDE0>> damage!
# <built-in method capitalize of str object at 0x00000215409A3960> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F6B0>> damage!
# <built-in method capitalize of str object at 0x00000215409C4090> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2EDE0>> damage!
# <built-in method capitalize of str object at 0x00000215409A3960> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F6B0>> damage!
# <built-in method capitalize of str object at 0x00000215409C4090> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2EDE0>> damage!
# <built-in method capitalize of str object at 0x00000215409A3960> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F6B0>> damage!
# <built-in method capitalize of str object at 0x00000215409C4090> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2EDE0>> damage!
# <built-in method capitalize of str object at 0x00000215409A3960> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F6B0>> damage!
# <built-in method capitalize of str object at 0x00000215409C4090> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2EDE0>> damage!
# <built-in method capitalize of str object at 0x00000215409A3960> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F6B0>> damage!
# <built-in method capitalize of str object at 0x00000215409C4090> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2EDE0>> damage!
# <built-in method capitalize of str object at 0x00000215409A3960> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F6B0>> damage!
# <built-in method capitalize of str object at 0x00000215409C4090> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2EDE0>> damage!
# <built-in method capitalize of str object at 0x00000215409A3960> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F6B0>> damage!
# <built-in method capitalize of str object at 0x00000215409C4090> swings at <built-in method capitalize of str object at 0x00000215409A3960> dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2EDE0>> damage!
# <built-in method capitalize of str object at 0x00000215409A3960> is defeated! <built-in method capitalize of str object at 0x00000215409C4090> is victorious!

# %%
#Practicing organizing code by using classes, I want to create monsters that can attack eachother, but each have different attributes, abilities ect.

class Monster:
    #Define the monster
    def __init__(self, monster, level, category, armour_level, life, weapon_level):
        self.monster = monster
        self.level = level
        self.category = category
        self.armour_level = armour_level
        self.life = life
        self.weapon_level = weapon_level

    def damage(self, life_damage):
        self.life -= life_damage
        return self.life

    def attack(self, other):
        damage_dealt = self.weapon_level - other.armour_level
        if damage_dealt > 0:
            other.damage(damage_dealt)
        else:
            other.damage(1)
    


ogre = Monster(monster = 'ogre', level = 50, category = 'giant', armour_level = 1,life = 100, weapon_level = 6,)

human = Monster(monster = 'Chad', level = 30, category = 'Humanoid', armour_level = 3, life = 100, weapon_level = 3,)

bear = Monster(monster = 'Bear', level = 20, category = 'Mammal', armour_level = 0, life = 100, weapon_level = 3,)

gorilla = Monster(monster = 'Harambe', level = 30, category = 'Mammal', armour_level = 3, life = 100, weapon_level = 3,)

garden_gnome = Monster(monster = 'Gnome', level = 100, category = 'Lawn Decor', armour_level = 6, life = 100, weapon_level = 6,)

def main() -> None:
    monsters = {
        'ogre': ogre,
        'human': human,
        'bear': bear,
        'gorilla': gorilla,
        'garden gnome': garden_gnome
    }

    Fighter1 = input('choose your monster, "Ogre, Human, Bear, Gorilla, or Garden Gnome: ').strip().lower()
    Fighter2 = input('choose opposing monster, "Ogre, Human, Bear, Gorilla, or Garden Gnome: ').strip().lower()

    if Fighter1 in monsters and Fighter2 in monsters:
        fighter1 = monsters[Fighter1]
        fighter2 = monsters[Fighter2]
        
        while fighter1.life > 0 and fighter2.life > 0:

            fighter1.attack(fighter2)
            print(f'{fighter1.monster} swings at {fighter2.monster} dealing {fighter1.attack} damage!')

            if fighter2.life <= 0:
                print(f'{fighter2.monster} is defeated! {fighter1.monster} is victorious!')
                break
            
            fighter2.attack(fighter1)
            print(f'{fighter2.monster} swings at {fighter2.monster} dealing {fighter2.attack} damage!')

            if fighter1.life <= 0:
                print(f'{fighter1.monster} is defeated! {fighter2.monster} is victorious!')
        

if __name__ == '__main__':
    main()
# Out:
# Gnome swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B0CA70>> damage!
# Bear swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F050>> damage!
# Gnome swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B0CA70>> damage!
# Bear swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F050>> damage!
# Gnome swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B0CA70>> damage!
# Bear swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F050>> damage!
# Gnome swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B0CA70>> damage!
# Bear swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F050>> damage!
# Gnome swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B0CA70>> damage!
# Bear swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F050>> damage!
# Gnome swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B0CA70>> damage!
# Bear swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F050>> damage!
# Gnome swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B0CA70>> damage!
# Bear swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F050>> damage!
# Gnome swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B0CA70>> damage!
# Bear swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F050>> damage!
# Gnome swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B0CA70>> damage!
# Bear swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F050>> damage!
# Gnome swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B0CA70>> damage!
# Bear swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F050>> damage!
# Gnome swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B0CA70>> damage!
# Bear swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F050>> damage!
# Gnome swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B0CA70>> damage!
# Bear swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F050>> damage!
# Gnome swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B0CA70>> damage!
# Bear swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F050>> damage!
# Gnome swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B0CA70>> damage!
# Bear swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F050>> damage!
# Gnome swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B0CA70>> damage!
# Bear swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F050>> damage!
# Gnome swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B0CA70>> damage!
# Bear swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B2F050>> damage!
# Gnome swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B0CA70>> damage!
# Bear is defeated! Gnome is victorious!

# %%
#Practicing organizing code by using classes, I want to create monsters that can attack eachother, but each have different attributes, abilities ect.

class Monster:
    #Define the monster
    def __init__(self, monster, level, category, armour_level, life, weapon_level):
        self.monster = monster
        self.level = level
        self.category = category
        self.armour_level = armour_level
        self.life = life
        self.weapon_level = weapon_level

    def damage(self, life_damage):
        self.life -= life_damage
        return self.life

    def attack(self, other):
        damage_dealt = self.weapon_level - other.armour_level
        if damage_dealt > 0:
            other.damage(damage_dealt)
            return(damage_dealt)
        else:
            other.damage(1)
            return(damage_dealt)
    


ogre = Monster(monster = 'ogre', level = 50, category = 'giant', armour_level = 1,life = 100, weapon_level = 6,)

human = Monster(monster = 'Chad', level = 30, category = 'Humanoid', armour_level = 3, life = 100, weapon_level = 3,)

bear = Monster(monster = 'Bear', level = 20, category = 'Mammal', armour_level = 0, life = 100, weapon_level = 3,)

gorilla = Monster(monster = 'Harambe', level = 30, category = 'Mammal', armour_level = 3, life = 100, weapon_level = 3,)

garden_gnome = Monster(monster = 'Gnome', level = 100, category = 'Lawn Decor', armour_level = 6, life = 100, weapon_level = 6,)

def main() -> None:
    monsters = {
        'ogre': ogre,
        'human': human,
        'bear': bear,
        'gorilla': gorilla,
        'garden gnome': garden_gnome
    }

    Fighter1 = input('choose your monster, "Ogre, Human, Bear, Gorilla, or Garden Gnome: ').strip().lower()
    Fighter2 = input('choose opposing monster, "Ogre, Human, Bear, Gorilla, or Garden Gnome: ').strip().lower()

    if Fighter1 in monsters and Fighter2 in monsters:
        fighter1 = monsters[Fighter1]
        fighter2 = monsters[Fighter2]
        
        while fighter1.life > 0 and fighter2.life > 0:

            fighter1.attack(fighter2)
            print(f'{fighter1.monster} swings at {fighter2.monster} dealing {fighter1.attack} damage!')

            if fighter2.life <= 0:
                print(f'{fighter2.monster} is defeated! {fighter1.monster} is victorious!')
                break
            
            fighter2.attack(fighter1)
            print(f'{fighter2.monster} swings at {fighter2.monster} dealing {fighter2.monster} damage!')

            if fighter1.life <= 0:
                print(f'{fighter1.monster} is defeated! {fighter2.monster} is victorious!')
        

if __name__ == '__main__':
    main()
# Out:
# ogre swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B32CC0>> damage!
# Bear swings at Bear dealing Bear damage!
# ogre swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B32CC0>> damage!
# Bear swings at Bear dealing Bear damage!
# ogre swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B32CC0>> damage!
# Bear swings at Bear dealing Bear damage!
# ogre swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B32CC0>> damage!
# Bear swings at Bear dealing Bear damage!
# ogre swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B32CC0>> damage!
# Bear swings at Bear dealing Bear damage!
# ogre swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B32CC0>> damage!
# Bear swings at Bear dealing Bear damage!
# ogre swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B32CC0>> damage!
# Bear swings at Bear dealing Bear damage!
# ogre swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B32CC0>> damage!
# Bear swings at Bear dealing Bear damage!
# ogre swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B32CC0>> damage!
# Bear swings at Bear dealing Bear damage!
# ogre swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B32CC0>> damage!
# Bear swings at Bear dealing Bear damage!
# ogre swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B32CC0>> damage!
# Bear swings at Bear dealing Bear damage!
# ogre swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B32CC0>> damage!
# Bear swings at Bear dealing Bear damage!
# ogre swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B32CC0>> damage!
# Bear swings at Bear dealing Bear damage!
# ogre swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B32CC0>> damage!
# Bear swings at Bear dealing Bear damage!
# ogre swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B32CC0>> damage!
# Bear swings at Bear dealing Bear damage!
# ogre swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B32CC0>> damage!
# Bear swings at Bear dealing Bear damage!
# ogre swings at Bear dealing <bound method Monster.attack of <__main__.Monster object at 0x0000021540B32CC0>> damage!
# Bear is defeated! ogre is victorious!
